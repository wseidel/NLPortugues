# %% [markdown]
# <img src="https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/imagens/logo_nlportugues.png"  style="height:65%" align="right">
#
#
# # Lista 2 - NN & Backpropagation
# **Nome:** Wesley Seidel Carvalho
#
# **Numero Usp:** 6544342
#
#
# _________________________________________
#
# Antes de começar o exercício,  não se esqueça de instalar todos os pacotes necessários para a sua execução.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from sklearn.model_selection import train_test_split
# %matplotlib inline
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# ## Perceptron
#
# O perceptron é uma "rede neural" de um só neurônio.  No nosso caso, temos a rede mais simpes possível, com uma só entrada e uma só saída, sem ativação.
#
# Temos 100 dados que serão usados para treinar 300 épocas do percéptron.
#
# Vamos utilizar o modelo perceptron para aprender uma simples regressão linear, o objetivo é faze-lo aprender uma simples equação linear e tambem se acostumar com a sintaxe e funcionamento do TensorFlow

# %%
def f1(x):
    '''
    Funcao a ser aprendida
    '''
    return 5 + 10*x

# %%
xs = np.linspace(0,10,100)  # gera 100 valores no intervalo [0.10]
ys = f1(xs)                 # computa o valor de f1 nestes 100 valores
print(len(xs), "xs=", xs)
print(len(ys), "ys=", ys)
# Out:
# 100 xs= [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
#Definindo, compilando e treinando nosso modelo
model = tf.keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(units=1),
])

# model.compile(optimizer="adam", loss="mean_squared_error")
model.compile(optimizer="sgd", loss="mean_squared_error")
model.fit(xs,ys,epochs=300)
# Out:
# Epoch 1/300
# 4/4 [==============================] - 0s 1ms/step - loss: 974.0103
# Epoch 2/300
# 4/4 [==============================] - 0s 1ms/step - loss: 3.3168
# Epoch 3/300
# 4/4 [==============================] - 0s 1ms/step - loss: 3.1938
# Epoch 4/300
# 4/4 [==============================] - 0s 940us/step - loss: 3.1199
# Epoch 5/300
# 4/4 [==============================] - 0s 1ms/step - loss: 2.9695
# Epoch 6/300
# 4/4 [==============================] - 0s 867us/step - loss: 2.8799
# Epoch 7/300
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8037
# Epoch 8/300
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6121
# Epoch 9/300
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6217
# Epoch 10/300
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4132
# Epoch 11/300
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3359
# Epoch 12/300
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2285
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
to_predict = 17
print("prediction: "+ str(model.predict([to_predict]))+"      real value: " + str(f1(to_predict)))
# Out:
# prediction: [[175.01793]]      real value: 175

# %%
val = np.linspace(0,10,43)
model.evaluate(x=val, y=f1(val))
# Out:
# 2/2 [==============================] - 0s 1ms/step - loss: 2144.8782
# 2144.878173828125

# %% [markdown]
# A função `evaluate` retorna o "custo" (loss) da avaliação, definido na compilação.  Nesse caso, o valor reportado é o erro quadrático médio (MSE).

# %% [markdown]
# ## Aprendendo uma função não linear

# %%
def f2(x):
    '''
    Funcao não linear a ser aprendida
    '''
    return (x**2 + x*3 + 4)/200

# %%
x = np.linspace(0,10,100)
y = f2(x)
f2(6)
# Out:
# 0.29

# %% [markdown]
# # <font color='blue'>Questão 1 </font>
# Defina as camadas para esta rede neural e treine seu modelo, note que a saída unitária _não deve_ ter função de ativação (por que?).

# %%
model = tf.keras.Sequential([    
    keras.Input(shape=(1,)),
    #Seu código aqui
    # keras.layers.Dense(units=4, activation="relu"),
    keras.layers.Dense(units=4, activation="tanh"),
    keras.layers.Dense(1),
])

model.compile(optimizer="adam", loss="mean_squared_error")
model.fit(x,y,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.4136
# Epoch 2/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.3263
# Epoch 3/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.2393
# Epoch 4/400
# 4/4 [==============================] - 0s 918us/step - loss: 4.1546
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0694
# Epoch 6/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9868
# Epoch 7/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.9044
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8241
# Epoch 9/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7460
# Epoch 10/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.6673
# Epoch 11/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.5902
# Epoch 12/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.5140
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 4)                 8
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 5
# ...
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_val = np.linspace(0,10,63)
y_val = f2(x_val)
model.evaluate(x=x_val,y=y_val)
# Out:
# 2/2 [==============================] - 0s 948us/step - loss: 9.8968e-04
# 0.0009896799456328154

# %%
to_predict = 1
print("prediction: "+ str(model.predict([to_predict]))+"      real value: " + str(f2(to_predict)))
# Out:
# prediction: [[0.01657291]]      real value: 0.04

# %% [markdown]
# A camada de saída unitária não deve ter função de ativação por estarmos "aprendendo" uma função contínua.

# %% [markdown]
# ____________________________
# # <font color='blue'>Questão 2 </font>
#
#
#
# O que acontece se você muda as funções de ativação? Teste algumas diferentes e descreva seus resultados, em especial a tangente hiperbolica

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**
#
# Para tentar responder esta pergunta, realizei testes com a configuração de 1 camada oculta de apenas 2 nodes. Mantive o otimizador "adam", e a função loss ficou "mean_squared_error".
# Com isso definido, avaliei as diferentes funções de ativação obtidas da documentação:
#
# Seguem resultados das avaliações ordenados em ordem crescente:
#
#
# | Ativação | Loss |
# | -------- | ---- |
# | hard_sigmoid | 0.001218665624037385  |
# | relu         | 0.001430634525604546  |
# | softmax      | 0.0068061333149671555 |
# | tanh         | 0.007322477176785469  |
# | sigmoid      | 0.008437666110694408  |
# | elu          | 0.009117336012423038  |
# | selu         | 0.012986857444047928  |
# | softsign     | 0.01958272233605385   |
# | softplus     | 0.04176408424973488   |
# | linear       | 0.11557945609092712   |
# | swish        | 0.27850785851478577   |
# | exponential  | 60073.5546875         |
#
#
# Vemos que a depender da função escolhida, o resultado da avaliação após o treinamento altera bastante em comparação uns com outros.

# %% [markdown]
# O que acontece se você mudar a função de otimização? Teste diferentes funções e descreva seus resultados, em especial as funções SDG e RMSprop

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**
#
# Para esta pergunta realizei testes com a configuração de 1 camada oculta com 2 nodes utilizando a função de ativação "relu". Além disso mantive a função loss como "mean_squared_error".
#
# Com isso definido, avaliei as seguintes funções de otimização: adam, SDG, RMSprop.
#
# Seguem resultados das avaliações ordenados em ordem crescente:
#
#
#
# | Otmizador | Epoch 1 | Epoch 400 | Avaliação |
# | ------ | ------ | ------ | ------ |
# | Adam | 0.1057 | 0.0374 | 0.03782377392053604 |
# | SDG | 0.1034 | 0.0374 | 0.0378231555223465 |
# | RMSprop | 0.5485 | 0.0015 | 0.001661485293880105 |
#
# Aqui podemos verificar que para as configurações adotadas, não houveram diferenças significativas entre o resultado da avaliação comparando os otimizadores "adam" e o "SDG". No entanto, ao utilizar o otimizador "RMSprop" podemos perceber algumas coisas:
#
# 1. **Avaliação:** O resultado da avaliação do "RMSprop" ficou bem menor (menos perda) se comparado aos outros dois testados
# 2. **Sobre convergência:** Os otimizadores "Adam"e "SDG" tiveram comportamento semelhante. No entando o "RMSprop" apesar de ter iniciado com uma perda bem maior se comparado aos outros dois otimizadores testados, convergiu para uma perda muito menor.

# %% [markdown]
# Volte a primeira parte desse notebook e troque a função de ativação da rede de uma camada (pérceptron) de sdg para adam, o que acontece?

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**
#
# Comparando o resultado da avaliação, temos que com "sdg" a avaliação estava com o valor de 1.7720903997542337e-05 e após a mudança para o otimizador "adam" o resultado da avaliação (loss) aumentou bastante, no meu teste para foi para o valor 2196.7900390625.

# %% [markdown]
# A avaliação de performance que realizamos foi apenas para pontos contidos no mesmo intervalo que o conjunto de treino, ou seja, foi apenas uma interpolação. Sem alterar sua rede repita o teste realizando uma extrapolação, com pontos fora do intervalo [0;10] e descreva seus resultados. O que aconteceu com a performance?

# %%
def f2(x):
    return (x**2 + x*3 + 4)/200

def train(x, y, _optimizer="adam", _units=2, _activation_l1="relu"):
    model = tf.keras.Sequential([ 
        keras.Input(shape=(1,)),
        # Seu código aqui
        keras.layers.Dense(units=_units, activation=_activation_l1),
        keras.layers.Dense(1),
    ])

    model.compile(optimizer=_optimizer, loss="mean_squared_error")
    model.fit(x,y,epochs=400)
    return model


x_train = np.linspace(0,10,100)
y_train = f2(x_train)

x_val = np.linspace(20,30,63)
y_val = f2(x_val)

optimizers = ['SGD', 'RMSprop', 'Adam']

results = []
for opt in optimizers:
    model = train(x_train, y_train, opt, 2, "relu" )
    loss = model.evaluate(x=x_val,y=y_val)

    print(f"Otimizador: #{opt} Loss: #{loss}")
    results.append(f"Otimizador: #{opt} Loss: #{loss}")

print(results)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 1ms/step - loss: 5.0630
# Epoch 2/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0200
# Epoch 3/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 6/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 7/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 9/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 10/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 11/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 12/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0019
# ...

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**
#
# Configuração: Mantendo 1 camada oculta com 2 nodes utilizando a função de ativação "relu" e função loss como "mean_squared_error" e treinando no espaço [0;10].
#
# Com isso definido, avaliei as seguintes funções de otimização: adam, SDG, RMSprop para o espaço [20;30].
#
# Segue a tabela comparativa dos resultados:
#
# | Otimizador | Avaliação [0..10]    | Avaliação  [20..30] |
# | ------     | ------               | ------               |
# | Adam       | 0.03782377392053604  | 10.062873840332031   |
# | SDG        | 0.0378231555223465   | 11.478386878967285   |
# | RMSprop    | 0.001661485293880105 | 13.007095336914062   |
#
# Aqui podemos perceber que o otimizador "Adam" foi o que menos perdeu eficácia se comparado aos outros dois, mas mesmo assim a perda foi bastante significativa.
# Especificamente no resultado anotado acima, é um ponto interessante é que o otimizador "RMSprop" que nos experimentos anteriores se apresentou melhor na interpolação, agora na extrapolação, especificamente para o experimento acima, ele foi o que se apresentou menos eficiente em termos de perda.
#
# Mas depois deste texto, ao rodar outras vezes o experimento, percebi que não é característica própria do "RMSProp" ser o que mais se difere entre a avaliação extrapolada e interpolada. Houveram casos nos quais os outros otmizadores apresentaram diferenças maiores do que a do "RMSprop".

# %% [markdown]
# # Prevendo se vai chover na Austrália

# %% [markdown]
# ## Pré processamento dos dados
# Já definimos uma função basica para lhe ajudar a explorar os dados, você precisara escrever uma função para carregar os dados, uma de pré-processamento e outra para fazer a separação em teste e treino.

# %%
def visualize_data(data):
    """Gera graficos das distribuicoes das features e salva em disco"""

    ibm_pltt = ['#648FFF', '#785EF0', '#DC267F',
                '#FE6100', '#FFB000']  # Paleta colorblind-friendly
    plt.figure(figsize=(8, 6))

    # RainToday:
    sns.set()
    sns.set_palette(sns.color_palette([ibm_pltt[2], ibm_pltt[0]]))
    sns.countplot(data.RainToday)
    plt.xlabel('Choveu Hoje?')
    plt.ylabel('Contagem')
    plt.title("Valores de 'RainToday' para os dados pré-processados")
    plt.savefig('data_RainToday.png')
    plt.clf()

    # RainTomorrow:
    sns.set()
    sns.set_palette(sns.color_palette([ibm_pltt[3], ibm_pltt[1]]))
    sns.countplot(data.RainTomorrow)
    plt.xlabel('Choverá Amanhã?')
    plt.ylabel('Contagem')
    plt.title("Valores de 'RainTomorrow' para os dados pré-processados")
    plt.savefig('data_Rainomorrow.png')
    plt.clf()

    # Humidity3pm:
    sns.set()
    sns.distplot(data.Humidity3pm, color=ibm_pltt[0])
    plt.xlabel('Umidade às 3PM')
    plt.ylabel('Densidade normalizada')
    plt.title("Distribuição da variável 'Humidity3pm' para os dados pré-processados")
    plt.savefig('data_Humidity3pm.png')
    plt.clf()

    # Pressure9am:
    sns.set()
    sns.distplot(data.Pressure9am, color=ibm_pltt[4])
    plt.xlabel('Pressão atmosférica às 9AM')
    plt.ylabel('Densidade normalizada')
    plt.title("Distribuição da variável 'Pressure9amm' para os dados pré-processados")
    plt.savefig('data_Pressure9am.png')
    plt.clf()

    # Rainfall:
    sns.set()
    sns.distplot(data.Rainfall, color=ibm_pltt[1], bins=500, kde=False)
    plt.xlim(0, 10)
    plt.xlabel('Pluviosidade')
    plt.ylabel('Densidade normalizada')
    plt.title("Distribuição da variável 'Rainfall' para os dados pré-processados")
    plt.savefig('data_Rainfall.png')
    plt.clf()

    return

# %% [markdown]
# # <font color='blue'>Questão 3 </font>
# Complete as funções aqui descritas seguindo a assinatura sugerida
#
# Para separar em treino e teste, de uma olhada na função [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) do Scikit-Learn

# %%
from sklearn.model_selection import train_test_split

def load_data(data_path='data/weatherAUS.csv')-> pd.DataFrame:
    """Funcao que importa dados de um arquivo csv, usando pandas"""
    raw_data = pd.read_csv(data_path)  
    return raw_data

def pre_processing(raw_data:pd.DataFrame)-> pd.DataFrame:
    """Funcao que filtra e limpa os dados meteorologicos para o treinamento"""
    #Seu código aqui
#     processed_data = raw_data[['RainToday', 'RainTomorrow', 'Humidity3pm', 'Pressure9am', 'Rainfall']]
    processed_data = raw_data[['RainToday', 'RainTomorrow', 'Humidity3pm', 'Pressure9am', 'Rainfall']]
    processed_data = processed_data.replace(('Yes', 'No'), (1, 0))

    processed_data.dropna(inplace=True)


    return processed_data

def split_data(data:pd.DataFrame, val_size= 0.2)-> np.array:
    """Funcao que separa seus dados em teste e treino conforme a proporcao val_size"""
    #Seu código aqui
    y_column = 'RainTomorrow'
    x_train, x_val, y_train, y_val = train_test_split(
        data.drop(columns = [y_column], axis = 1), 
        data[y_column], 
        test_size=val_size)
    return x_train, x_val, y_train, y_val

# %%
# %matplotlib inline
df = load_data()
# visualize_data(df)
df = pre_processing(df)
# visualize_data(df)
x_train, x_val, y_train, y_val = split_data(df,)
y_train
# Out:
# 82666     1
# 45382     0
# 95261     0
# 120412    0
# 127223    0
#          ..
# 135140    0
# 43789     0
# 99767     1
# 105968    0
# 104422    0
# Name: RainTomorrow, Length: 99751, dtype: int64

# %% [markdown]
# # <font color='blue'>Questão 4 </font>
# Agora que você ja ganhou uma familiaridade com a API Keras, escreva sozinho do começo ao fim um modelo que ira dizer se amanhã vai chover ou não e avalie sua performance.

# %%
# Seu código aqui
def train_w(x, y, _optimizer="adam", hlayers=[]): 
    sequential = [keras.Input(shape=(4,))]
    for hl in hlayers:
        sequential.append( keras.layers.Dense(units=hl[0], activation=hl[1]) )
    sequential.append( keras.layers.Dense(1, activation='sigmoid' ))

    model = tf.keras.Sequential(sequential)

    model.compile(optimizer=_optimizer, loss="mean_squared_error")
    model.fit(x,y,epochs=10)
    return model


optimizers = ['SGD', 'RMSprop', 'Adam']
# optimizers = ['SGD']

results = []
for opt in optimizers:
#     model = train_w(x_train, y_train, opt, [[6, "relu"], [6, "tanh"]] )
    model = train_w(x_train, y_train, opt, [[6, "relu"]] )
    loss = model.evaluate(x=x_val,y=y_val)

    print(f"Otimizador: #{opt} Loss: #{loss}")
    results.append(f"Otimizador: #{opt} Loss: #{loss}")

# erro quadrático médio (MSE). 
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-29f0d5fc3135> in <module>
#      19 for opt in optimizers:
#      20 #     model = train_w(x_train, y_train, opt, [[6, "relu"], [6, "tanh"]] )
# ---> 21     model = train_w(x_train, y_train, opt, [[6, "relu"]] )
#      22     loss = model.evaluate(x=x_val,y=y_val)
#      23
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# Utiliando o código acima, realizei 12 testes para avaliação do model. Segue:
#
# ### A) 1 camada, [6 nodes relu], 10 epocas
# 1. SGD        Loss: 0.7761247754096985
# 2. RMSprop    Loss: 0.22387520968914032
# 3. Adam       Loss: 0.22387520968914032
#
# ### B) 1 camada, [6 nodes tanh], 10 epocas
# 1. SGD        Loss: 0.17384228110313416
# 2. RMSprop    Loss: 0.17377954721450806
# 3. Adam       Loss: 0.1738024204969406
#
# ### C) 2 camadas, [6 nodes tanh], [6 nodes relu], 10 epocas
# 1. SGD        Loss: 0.17376703023910522
# 2. RMSprop    Loss: 0.13875243067741394
# 3. Adam       Loss: 0.13046732544898987
#
# ### D) 2 camadas, [6 nodes relu], [6 nodes tanh], 10 epocas
# 1. SGD        Loss: 0.17377407848834991
# 2. RMSprop    Loss: 0.13230730593204498
# 3. Adam       Loss: 0.1737888604402542
#
#
# Com os testes realizados, utilizando apenas 10 épocas, temos que o experimento B3 apresentou o modelo com menor perda, neste caso com apenas erro quadrático médio de 0.13046732544898987.
